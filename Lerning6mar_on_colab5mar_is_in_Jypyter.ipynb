# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthisl/Oceanographic-Analysis-Projects/blob/Master/Lerning6mar_on_colab5mar_is_in_Jypyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lerning6mar, Mar17 << Main Title , Lerning5mar is in Jupyter ;
# Project by Keerthi Abe
## Section 1
### Subsection a

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 3))
plt.plot([1, 2, 3, 4], [10, 20, 35, 30])
plt.title('Simple Line Plot Mar17')
plt.xlabel('X axis Ho')
plt.ylabel('Y axis Ver')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Load a sample dataset
tips = sns.load_dataset('tips')

# Create a statistical visualization
plt.figure(figsize=(5, 3))
sns.scatterplot(x='total_bill', y='tip', hue='time', data=tips)
plt.title('Tips vs Total Bill')
plt.show()

# %% [markdown]
# The code snippet you provided uses the seaborn library (sns) to load a sample dataset named 'tips' and create a scatterplot. To display a few lines of the dataset before plotting, you can use the .head() method from the pandas library, which is implicitly used by seaborn when loading datasets. This method retrieves the first few rows of the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a sample dataset
tips = sns.load_dataset('tips')

# Display the first few lines of the dataset
print(tips.head()) # To display a few lines of the dataset before plotting, head() method from the pandas library, which is implicitly used by seaborn when loading
print("----------")

# Create a statistical visualization
plt.figure(figsize=(5, 3))
sns.scatterplot(x='total_bill', y='tip', hue='time', data=tips)
plt.title('Tips vs Total Bill by KLa')
plt.show()

# %%
import plotly.express as px

# Create an interactive scatter plot
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
                title="Iris Dataset - Sepal Dimensions")
fig.show()

# %% [markdown]
# Your request involves displaying a few lines of data from the dataset before generating an interactive scatter plot using plotly.express. I will provide a clear and structured explanation, followed by the modified code to meet your requirement.
# Understanding the Code:
#
# The code you provided uses plotly.express (px), a high-level interface for creating interactive visualizations in Python. Specifically:
#
#     px.data.iris() loads a sample dataset, the Iris dataset, as a pandas DataFrame.
#     px.scatter() creates an interactive scatter plot with specified x-axis (sepal_width), y-axis (sepal_length), and color differentiation (species).
#     fig.show() renders the interactive plot.
#
# To read a few lines of the data before plotting, you can leverage the pandas DataFrame method .head(), which is available since the dataset is loaded as a DataFrame.

# %%
import plotly.express as px

# Load the Iris dataset
df = px.data.iris()

# Display the first few lines of the dataset
print(df.head())

# Create an interactive scatter plot
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
                 title="Iris Dataset - Sepal Dimensions")
fig.show()

# %%
# !pip install folium
import folium

# Create a map centered at the specified location (Sri Lanka coordinates)
m = folium.Map(location=[7.9569, 80.7597], zoom_start=10)

# Add a marker at the same location
folium.Marker([7.9569, 80.7597], popup="Sri Lanka - Central Point").add_to(m)

# Display the map
# KLA created seperate project with world map, location cordinates

# %% [markdown]
# Your request involves displaying a few lines of data before creating a map using the folium library. However, unlike the previous examples with seaborn or plotly.express, your current code does not explicitly load a dataset (e.g., a pandas DataFrame or similar structure). Instead, it directly defines a map and a marker using hardcoded coordinates for Sri Lanka. To provide a meaningful response, I will interpret your request as wanting to inspect some form of data related to the map—such as the coordinates—before plotting, and I will structure the solution accordingly.
# Understanding the Code:
#
# The code you provided uses folium, a Python library for creating interactive maps based on Leaflet.js:
#
#     !pip install folium: This installs the folium library if it’s not already present (necessary in some environments, though pre-installed in Google Colab as of recent updates).
#     folium.Map(): Creates a map centered at the coordinates [7.9569, 80.7597] (approximately central Sri Lanka) with a specified zoom level (zoom_start=10).
#     folium.Marker(): Adds a marker at the same coordinates with a popup label, attached to the map object m.
#
# Since no dataset is loaded, the "data" in this context is the coordinates and attributes used for the map and marker. I will modify the code to display this information before rendering the map.
# Modified Code:
#
# Here is the updated code to print the coordinates and marker details before displaying the map:

# %%
# !pip install folium  # Install folium if not already present (optional in Colab)
import folium

# Define the data (coordinates and marker details)
location_data = {
    "latitude": 7.9569,
    "longitude": 80.7597,
    "description": "Sri Lanka - Central Point"
}

# Display the data
print("Data to be plotted on the map:")
for key, value in location_data.items():
    print(f"{key}: {value}")

# Create a map centered at the specified location
m = folium.Map(location=[location_data["latitude"], location_data["longitude"]], zoom_start=10)

# Add a marker at the same location
folium.Marker(
    [location_data["latitude"], location_data["longitude"]],
    popup=location_data["description"]
).add_to(m)

# Display the map
m

# %%
# !pip install cartopy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

plt.figure(figsize=(5, 3))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines()
plt.title('World Map with Cartopy')
plt.show()

# %% [markdown]
# Your request involves displaying a few lines of data before generating a map using `cartopy`. Similar to the previous `folium` example, your current code does not load an explicit dataset (e.g., a table of coordinates or geographic data). Instead, it uses `cartopy` to create a basic world map with coastlines and gridlines. To address your request, I will interpret "data" as the key parameters or features used in the plot—such as the map projection and geographic elements—and display them before rendering the map.
#
# ### Understanding the Code:
# The code you provided uses `cartopy`, a Python library for geospatial data visualization, integrated with `matplotlib`:
# - `!pip install cartopy`: Installs `cartopy` if not already present (necessary in some environments, though it may require additional configuration in Google Colab).
# - `plt.axes(projection=ccrs.PlateCarree())`: Sets up a map with the Plate Carrée projection, a simple cylindrical projection.
# - `ax.coastlines()` and `ax.gridlines()`: Add coastlines and gridlines to the map.
# - `plt.show()`: Displays the resulting map.
#
# Since no tabular dataset is loaded, I will modify the code to print relevant configuration details (e.g., projection type and features) as "data" before plotting.
#
# ### Modified Code:
# Here is the updated code to display key map configuration details before rendering the map:
#
#
# ### Explanation:
# 1. **Defining the Data**:
#    - A dictionary (`map_config`) is created to store the key parameters used in the plot: the projection type, figure size, map features, and title. This serves as a proxy for "data" in the absence of an external dataset.
#    - This approach allows you to inspect the configuration before the map is drawn.
#
# 2. **Displaying the Data**:
#    - The `print()` statements output the contents of `map_config` in a clear format. Example output:
#      ```
#      Map configuration data:
#      projection: PlateCarree
#      figure_size: (5, 3)
#      features: ['coastlines', 'gridlines']
#      title: World Map with Cartopy
#      ```
#    - This fulfills your request to "read a few lines of data" by showing the settings applied to the map.
#
# 3. **Creating and Displaying the Map**:
#    - The map is constructed as in your original code, using the `PlateCarree` projection, coastlines, and gridlines, with the figure size and title specified.
#    - `plt.show()` renders the map, which will display a basic world map with the outlined features.
#
# ### Compatibility with Google Colab:
# - **Cartopy Installation**: As of March 17, 2025, `cartopy` is not pre-installed in Google Colab by default, unlike `matplotlib` or `seaborn`. The `!pip install cartopy` command attempts to install it, but note that `cartopy` has system-level dependencies (e.g., GEOS, PROJ) that may not install cleanly in Colab without additional configuration. In practice, you might encounter errors, and a workaround (e.g., using a custom runtime or alternative libraries like `folium`) may be needed. For this response, I assume the installation succeeds or is pre-configured.
# - **Display**: If `cartopy` is installed, the map will display correctly in a Colab cell, similar to `matplotlib` plots.
#
# ### Alternative Interpretation:
# If you intended to load and display a specific geospatial dataset (e.g., a CSV with latitude/longitude points or a shapefile), please provide details, and I can adjust the solution. For example, with a dataset like:
#
# ```csv
# latitude,longitude,name
# 7.9569,80.7597,Sri Lanka
# 40.7128,-74.0060,New York
# ```
#
# You could use `pandas` to read it, display `df.head()`, and plot points with `ax.scatter()`. Without such a dataset, I’ve focused on the map’s configuration as the "data."
#
# ### Conclusion:
# The modified code displays the map’s configuration details before rendering a world map with `cartopy`. This aligns with your request given the absence of an explicit dataset in your original code. If you have a specific dataset in mind or encounter issues with `cartopy` in Colab, please let me know, and I will provide further assistance.

# %%
# !pip install cartopy  # Install cartopy if not already present
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Define the map configuration data
map_config = {
    "projection": "PlateCarree",
    "figure_size": (5, 3),
    "features": ["coastlines", "gridlines"],
    "title": "World Map with Cartopy"
}

# Display the configuration data
print("Map configuration data:")
for key, value in map_config.items():
    print(f"{key}: {value}")

# Create the map
plt.figure(figsize=map_config["figure_size"])
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines()
plt.title(map_config["title"])
plt.show()
